# %% [markdown]
# Import the required libraries and modules

# %%
import sys
sys.path.insert(0, '..')
import zipfile
import numpy as np
import pandas as pd
import xgboost as xgb
import src.utilities.data_cleaning as dc
import src.utilities.outlier_handler as oh

# %% [markdown]
# Load the data

# %%
train_zip = zipfile.ZipFile('../data/raw/sf-crime.zip').open('train.csv')
train_data = pd.read_csv(train_zip)
pd.set_option('display.max_columns', 37)

# %% [markdown]
# Summary of the data

# %%
train_data.info()
train_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878049 entries, 0 to 878048
# Data columns (total 9 columns):
# Dates         878049 non-null object
# Category      878049 non-null object
# Descript      878049 non-null object
# DayOfWeek     878049 non-null object
# PdDistrict    878049 non-null object
# Resolution    878049 non-null object
# Address       878049 non-null object
# X             878049 non-null float64
# Y             878049 non-null float64
# dtypes: float64(2), object(7)
# memory usage: 60.3+ MB
#                    X              Y
# count  878049.000000  878049.000000
# mean     -122.422616      37.771020
# std         0.030354       0.456893
# min      -122.513642      37.707879
# 25%      -122.432952      37.752427
# 50%      -122.416420      37.775421
# 75%      -122.406959      37.784369
# max      -120.500000      90.000000

# %% [markdown]
# Exploratory Data Analysis

# %%
# TODO:
train_data = train_data.drop(columns = ['Descript', 'Resolution'])

# %% [markdown]
# Handle X and Y outliers

# %%
# handle_outliers() returns the processed dataframe and calculated mean coord. by district
result_tuple = oh.handle_outliers(train_data)
train_data = result_tuple[0]
train_data.describe()
# Out:
#                    X              Y
# count  878049.000000  878049.000000
# mean     -122.422763      37.767035
# std         0.025285       0.024164
# min      -122.513642      37.707879
# 25%      -122.432952      37.752427
# 50%      -122.416420      37.775421
# 75%      -122.406959      37.784368
# max      -122.364937      37.819975

# %% [markdown]
# Data pre-processing and feature engineering

# %%
train_data = dc.main_clean(train_data, center_scale = False)

# %% [markdown]
# Model Fitting and Prediction

# %%
category = pd.factorize(train_data['Category'], sort = True)
y_train = pd.Series(category[0]).astype('category')
X_train = train_data.drop(columns = 'Category', axis = 1)

# %% [markdown]
# Train the best model

# %%
clf = xgb.XGBClassifier(max_depth = 12, learning_rate = 0.05, n_estimators = 505, 
                        objective ='multi:softmax', gamma = 0.75, min_child_weight = 3, 
                        subsample = 0.75, colsample_bytree = 0.8, reg_alpha = 5, 
                        reg_lambda = 1.8, seed = 2019, n_jobs = -1)
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0.75,
#               learning_rate=0.05, max_delta_step=0, max_depth=12,
#               min_child_weight=3, missing=None, n_estimators=1, n_jobs=-1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=5, reg_lambda=1.8, scale_pos_weight=1, seed=2019,
#               silent=None, subsample=0.75, verbosity=1)

# %% [markdown]
# Load test data and pre-process

# %%
test_zip = zipfile.ZipFile('../data/raw/sf-crime.zip').open('test.csv')
test_data = pd.read_csv(test_zip)
test_data.describe()
# Out:
#                   Id              X              Y
# count  884262.000000  884262.000000  884262.000000
# mean   442130.500000    -122.422693      37.771476
# std    255264.596205       0.030985       0.484824
# min         0.000000    -122.513642      37.707879
# 25%    221065.250000    -122.433069      37.752374
# 50%    442130.500000    -122.416517      37.775421
# 75%    663195.750000    -122.406959      37.784353
# max    884261.000000    -120.500000      90.000000

# %% [markdown]
# Handle X and Y outliers using the mean coordinates obtained from train data

# %%
test_data = oh.handle_outliers(test_data, avg_XY = result_tuple[1])[0]
test_data = dc.main_clean(test_data, center_scale = False)
test_data.describe()
# Out:
#                   Id              X              Y  PdDistrict_BAYVIEW  \
# count  884262.000000  884262.000000  884262.000000       884262.000000
# mean   442130.500000    -122.422858      37.766986            0.101317
# std    255264.596205       0.025345       0.024179            0.301749
# min         0.000000    -122.513642      37.707879            0.000000
# 25%    221065.250000    -122.433070      37.752361            0.000000
# 50%    442130.500000    -122.416517      37.775421            0.000000
# 75%    663195.750000    -122.406959      37.784353            0.000000
# max    884261.000000    -122.364751      37.820621            1.000000
#
#        PdDistrict_CENTRAL  PdDistrict_INGLESIDE  PdDistrict_MISSION  \
# count       884262.000000         884262.000000       884262.000000
# mean             0.097403              0.090566            0.136214
# std              0.296506              0.286991            0.343016
# min              0.000000              0.000000            0.000000
# 25%              0.000000              0.000000            0.000000
# 50%              0.000000              0.000000            0.000000
# 75%              0.000000              0.000000            0.000000
# max              1.000000              1.000000            1.000000
#
#        PdDistrict_NORTHERN  PdDistrict_PARK  PdDistrict_RICHMOND  \
# count        884262.000000    884262.000000        884262.000000
# mean              0.121024         0.056769             0.050858
# std               0.326155         0.231402             0.219708
# min               0.000000         0.000000             0.000000
# 25%               0.000000         0.000000             0.000000
# 50%               0.000000         0.000000             0.000000
# 75%               0.000000         0.000000             0.000000
# max               1.000000         1.000000             1.000000
#
#        PdDistrict_SOUTHERN  PdDistrict_TARAVAL  PdDistrict_TENDERLOIN  \
# count        884262.000000       884262.000000          884262.000000
# mean              0.178065            0.075336               0.092447
# std               0.382568            0.263933               0.289655
# min               0.000000            0.000000               0.000000
# 25%               0.000000            0.000000               0.000000
# 50%               0.000000            0.000000               0.000000
# 75%               0.000000            0.000000               0.000000
# max               1.000000            1.000000               1.000000
#
#        Patrol_Division   Intersection    DayOfWeek_X    DayOfWeek_Y  \
# count    884262.000000  884262.000000  884262.000000  884262.000000
# mean          0.579505       0.296471      -0.021150       0.009007
# std           0.493639       0.456701       0.706397       0.707444
# min           0.000000       0.000000      -0.900969      -0.974928
# 25%           0.000000       0.000000      -0.900969      -0.781831
# 50%           1.000000       0.000000      -0.222521       0.000000
# 75%           1.000000       1.000000       0.623490       0.781831
# max           1.000000       1.000000       1.000000       0.974928
#
#          DayOfYear_X  ...         Hour_Y    00:00-05:59    06:00-17:59  \
# count  884262.000000  ...  884262.000000  884262.000000  884262.000000
# mean        0.012946  ...      -0.241627       0.143728       0.536253
# std         0.701209  ...       0.639708       0.350814       0.498684
# min        -0.999963  ...      -1.000000       0.000000       0.000000
# 25%        -0.683919  ...      -0.866025       0.000000       0.000000
# 50%         0.021516  ...      -0.382683       0.000000       1.000000
# 75%         0.714673  ...       0.258819       0.000000       1.000000
# max         1.000000  ...       1.000000       1.000000       1.000000
#
#          18:00-23:59      2003-2005      2006-2009      2010-2012  \
# count  884262.000000  884262.000000  884262.000000  884262.000000
# mean        0.320019       0.250387       0.316160       0.228678
# std         0.466484       0.433236       0.464976       0.419981
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         1.000000       1.000000       1.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#            2013-2016      Polar_Rho      Polar_Phi          X_R30  \
# count  884262.000000  884262.000000  884262.000000  884262.000000
# mean        0.204775     128.115971      -0.299233     -56.198880
# std         0.403538       0.024168       0.000198       0.023605
# min         0.000000     128.054347      -0.299767     -56.246055
# 25%         0.000000     128.103112      -0.299385     -56.215369
# 50%         0.000000     128.111894      -0.299278     -56.205762
# 75%         0.000000     128.125712      -0.299106     -56.184521
# max         1.000000     128.206104      -0.298650     -56.135906
#
#                Y_R30          X_R60          Y_R60       XY_PCA1  \
# count  884262.000000  884262.000000  884262.000000  8.842620e+05
# mean     -115.132043     105.085341     -73.285555 -4.808892e-14
# std         0.025880       0.026303       0.023133  2.668908e-02
# min      -115.220717     105.013650     -73.339157 -7.861527e-02
# 25%      -115.141947     105.066881     -73.300802 -1.930443e-02
# 50%      -115.124714     105.077221     -73.292835 -6.869091e-03
# 75%      -115.114528     105.095663     -73.271701  1.207638e-02
# max      -115.066358     105.176640     -73.218411  9.165545e-02
#
#             XY_PCA2  Nearest_Station  Nearest_Station_Bearing
# count  8.842620e+05    884262.000000            884262.000000
# mean   3.160258e-14         1.041684                -6.520268
# std    2.268669e-02         0.668142                99.884047
# min   -6.408853e-02         0.005755              -179.986817
# 25%   -1.380383e-02         0.542348               -92.190295
# 50%   -4.325124e-03         0.934336               -18.732671
# 75%    1.094741e-02         1.359485                81.771502
# max    7.059576e-02         4.663075               179.963528
#
# [8 rows x 38 columns]

# %% [markdown]
# Prediction

# %%
X_test = test_data.drop('Id', axis = 1)
y_pred = clf.predict_proba(X_test)

# %% [markdown]
# Save result

# %%
result = pd.DataFrame(y_pred)
result.insert(0, 'Id', test_data['Id'])
column_names = np.insert(category[1], 0, 'Id')
result.columns = column_names
# result.to_csv('submission.csv', index = False)
print(result)
# Out:
#             Id     ARSON   ASSAULT  BAD CHECKS   BRIBERY  BURGLARY  \
# 0            0  0.025148  0.028122    0.025122  0.025119  0.026352
# 3       ...        0.029363                 0.025083      0.025108
# 4       ...        0.029363                 0.025083      0.025108
# ...     ...             ...                      ...           ...
# 884257  ...        0.032527                 0.024829      0.024889
# 884258  ...        0.029114                 0.024767      0.025410
# 884259  ...        0.029173                 0.024952      0.024978
# 884260  ...        0.032671                 0.024940      0.024965
# 884261  ...        0.029024                 0.024825      0.024850
#
#         RECOVERED VEHICLE   ROBBERY   RUNAWAY  SECONDARY CODES  \
# 0                0.025241  0.025763  0.025206         0.025435
# 1                0.025024  0.025541  0.024989         0.025086
# 2                0.025049  0.025275  0.025030         0.025274
# 3                0.025213  0.025951  0.025177         0.025509
# 4                0.025213  0.025951  0.025177         0.025509
# ...                   ...       ...       ...              ...
# 884257           0.024830  0.026277  0.024923         0.025097
# 884258           0.024767  0.025171  0.024787         0.025410
# 884259           0.024957  0.025600  0.025059         0.025221
# 884260           0.024944  0.026148  0.025034         0.025587
# 884261           0.024825  0.025413  0.024844         0.025092
#
#         SEX OFFENSES FORCIBLE  SEX OFFENSES NON FORCIBLE  STOLEN PROPERTY  \
# 0                    0.025232                   0.025114         0.025287
# 1                    0.024950                   0.024899         0.025070
# 2                    0.025131                   0.025013         0.025185
# 3                    0.025204                   0.025086         0.025259
# 4                    0.025204                   0.025086         0.025259
# ...                       ...                        ...              ...
# 884257               0.026353                   0.024833         0.024921
# 884258               0.024969                   0.024770         0.024907
# 884259               0.025381                   0.024956         0.025044
# 884260               0.025587                   0.024943         0.025032
# 884261               0.025469                   0.024828         0.024916
#
#          SUICIDE  SUSPICIOUS OCC      TREA  TRESPASS  VANDALISM  \
# 0       0.025124        0.025766  0.025111  0.025226   0.026545
# 1       0.024908        0.025320  0.024895  0.024929   0.026317
# 2       0.025023        0.025484  0.025009  0.025231   0.026438
# 3       0.025096        0.026067  0.025082  0.025197   0.027180
# 4       0.025096        0.026067  0.025082  0.025197   0.027180
# ...          ...             ...       ...       ...        ...
# 884257  0.024843        0.026200  0.024829  0.024943   0.026247
# 884258  0.024780        0.025974  0.024766  0.024986   0.026181
# 884259  0.024965        0.026329  0.024952  0.025066   0.026663
# 884260  0.024953        0.026074  0.024939  0.025160   0.026364
# 884261  0.024838        0.026579  0.024824  0.024938   0.028376
#
#         VEHICLE THEFT  WARRANTS  WEAPON LAWS
# 0            0.025758  0.025769     0.025385
# 1            0.025537  0.027422     0.025916
# 2            0.025572  0.025321     0.025146
# 3            0.025734  0.026231     0.025415
# 4            0.025734  0.026231     0.025415
# ...               ...       ...          ...
# 884257       0.025737  0.025474     0.025137
# 884258       0.025410  0.025075     0.024901
# 884259       0.029819  0.025307     0.025282
# 884260       0.025629  0.025584     0.025587
# 884261       0.027912  0.025217     0.025014
#
# [884262 rows x 40 columns]
